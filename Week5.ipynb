# %% [markdown]
# <a href="https://colab.research.google.com/github/Iddamhaqi12/PCVK_Ganjil_23/blob/main/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import glob
from google.colab.patches import cv2_imshow

# %%
print(' Gamma Correction pada citra')
print('--------------------------------')
try:
  gamma = int(input('Masukkan nilai Gamma: '))
except ValueError:
   print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK_TI/dataset/female.tiff')

gamma_corrected = np.power((original / 255), 1/gamma)
gamma_corrected = (gamma_corrected * 255).astype(np.uint8)

final_frame=cv2.hconcat ((original,gamma_corrected))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# --------------------------------
# Masukkan nilai Gamma: 2
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
print(' Simulasi Image Depth ')
print('----------------------------------')
try:
 bit_depth = int(input('Masukkan nilai Bit Depth: '))
except ValueError:
 print('Error, not a number')

level = 255 / (pow(2,bit_depth)-1)
grayscale = cv2.imread('/content/drive/MyDrive/PCVK_TI/dataset/female.tiff', cv2.IMREAD_GRAYSCALE)
# depth_image = np.zeros(grayscale.shape, grayscale.dtype)

# for y in range(original.shape[0]):
#     for x in range(original.shape[1]):
#             depth_image[y,x]=np.clip(round(grayscale[y,x] / level) * level,0,255)

depth_image = np.round(grayscale/level) * level
depth_image = depth_image.astype(np.uint8)

final_frame=cv2.hconcat ((grayscale,depth_image))
cv2_imshow(final_frame)
# Out:
#  Simulasi Image Depth
# ----------------------------------
# Masukkan nilai Bit Depth: 2
# <PIL.Image.Image image mode=L size=512x256>

# %%
couple_img = cv2.imread('/content/drive/MyDrive/PCVK_TI/dataset/galaxy.jpg')

center1 = (170, 90) # h,v
radius1 = 96
center2 = (480, 100)
radius2 = 96

mask = np.zeros_like(couple_img)
cv2.circle(mask, center1, radius1, (255, 255, 255), -1)
cv2.circle(mask, center2, radius2, (255, 255, 255), -1)

masked_image = cv2.bitwise_and(couple_img, mask)

final_frame = cv2.hconcat((couple_img, mask,masked_image))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=930x256>

# %%
print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
 gamma = int(input('Masukkan nilai Gamma: '))
except ValueError:
 print('Error, not a number')

original = cv2.imread('/content/drive/MyDrive/PCVK_TI/dataset/galaxy.jpg')

gamma_corrected = np.power((original / 255), 1/gamma)
gamma_corrected = (gamma_corrected * 255).astype(np.uint8)

final_frame=cv2.hconcat ((original,gamma_corrected))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 2
# <PIL.Image.Image image mode=RGB size=620x256>

# %%
couple_img = cv2.imread('/content/drive/MyDrive/PCVK_TI/dataset/couple.tiff')

center1 = (170, 90) # h,v
radius1 = 96
center2 = (480, 100)
radius2 = 96

mask = np.zeros_like(couple_img)
cv2.circle(mask, center1, radius1, (255, 255, 255), -1)
cv2.circle(mask, center2, radius2, (255, 255, 255), -1)

masked_image = cv2.bitwise_and(couple_img, mask)

final_frame = cv2.hconcat((couple_img, mask,masked_image))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256>
